# %%
import pandas as pd
import requests
import os
import numpy as np

# %% [markdown]
# # Download Dataset for Portsmouth
#
# #### We create a directory where to store the datasets, and use requests.url to download the data from the DEFRA website
# #### This initial part of the notebook can be easily changed to consider other UK locations

# %%
dir_UKAIR = "./data/UKAIR"

# %%
os.mkdir(dir_UKAIR)

# %%
dir_UKAIR_po = dir_UKAIR+"/Portsmouth"
os.mkdir(dir_UKAIR_po)

# %%
file_url = "https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_"
suffix = ".csv?v=1"
file_prefix= "PO_"
for year in (range(2001, 2025)):
    file_name_to_save = f"{file_prefix}{year}.csv"
    with open(dir_UKAIR_po + "/" + file_name_to_save, "wb") as f:
        url = f"{file_url}{year}{suffix}"
        print('downloading: ', url)
        r = requests.get(url)
        f.write(r.content)
# Out:
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2001.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2002.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2003.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2004.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2005.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2006.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2007.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2008.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2009.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2010.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2011.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2012.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2013.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2014.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2015.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2016.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2017.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2018.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2019.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2020.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2021.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2022.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2023.csv?v=1
# downloading:  https://uk-air.defra.gov.uk/datastore/data_files/site_data/PMTH_2024.csv?v=1

# %% [markdown]
# # Load the datasets
# #### We make use of a dict and then concatenate the datasets

# %%
# Dictionary to store DataFrames 
dfs = {}

# %%
# Load the CSV into the dictionary 

for year in (range(2001, 2025)):
    file_path = f'{dir_UKAIR_po}/PO_{year}.csv'  
    dfs[year] = pd.read_csv(file_path, engine='python', skiprows=4)

# %%
# Concatenate the datasets
df_to_conc = []

for year in (range(2001, 2025)):
    file_path = f'{dir_UKAIR_po}/PO_{year}.csv'  
    df_to_conc.append(pd.read_csv(file_path, engine='python', skiprows=4))

# %%
df_port = pd.concat(df_to_conc, ignore_index=True)

# %%
df_port.head()
# Out:
#          Date   time  PM10 particulate matter (Hourly measured) status  \
# 0  01-01-2001  01:00                                       31.0      R
# 1  01-01-2001  02:00                                       25.0      R
# 2  01-01-2001  03:00                                       25.0      R
# 3  01-01-2001  04:00                                       22.0      R
# 4  01-01-2001  05:00                                       29.0      R
#
#               unit  Nitric oxide status.1 unit.1  Nitrogen dioxide status.2  \
# 0  ugm-3 (GRAV EQ)           1.0        R  ugm-3               6.0        R
# 1  ugm-3 (GRAV EQ)           0.0        R  ugm-3               8.0        R
# 2  ugm-3 (GRAV EQ)           0.0        R  ugm-3               6.0        R
# 3  ugm-3 (GRAV EQ)           0.0        R  ugm-3               6.0        R
# 4  ugm-3 (GRAV EQ)           0.0        R  ugm-3               6.0        R
#
#    ... unit.8  Volatile PM2.5 (Hourly measured) status.9 unit.9  \
# 0  ...    NaN                               NaN      NaN    NaN
# 1  ...    NaN                               NaN      NaN    NaN
# 2  ...    NaN                               NaN      NaN    NaN
# 3  ...    NaN                               NaN      NaN    NaN
# 4  ...    NaN                               NaN      NaN    NaN
#
#    PM<sub>10</sub> particulate matter (Hourly measured)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Non-volatile PM<sub>10</sub> (Hourly measured)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Non-volatile PM<sub>2.5</sub> (Hourly measured)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    PM<sub>2.5</sub> particulate matter (Hourly measured)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Volatile PM<sub>10</sub> (Hourly measured)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Volatile PM<sub>2.5</sub> (Hourly measured)
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# The dataset resolution is one hour.
# We can now save the dataset to use it in the DigitalTwin of the Portsmouth harbour

# %%
df_port.to_csv(dir_UKAIR+"AirQuality_digitaltwin_1h.csv")
