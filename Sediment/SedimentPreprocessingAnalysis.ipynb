# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dr = "/home/lolla/RemoteSensing_Environment_Projects/DigitalTwin/data/"

# %%
df_sed_L80 = pd.read_csv('L8_sediment_centre.csv')  
df_sed_L8h = pd.read_csv('L8_sediment_hayling.csv')  
df_sed_L80["date"] = pd.to_datetime(df_sed_L80['date'])
df_sed_L8h["date"] = pd.to_datetime(df_sed_L8h['date'])

# %%
df_sed_L8h.columns
# Out:
# Index(['date', 'satellite', 'NSMI_tot', 'NSMI_mean', 'NSMI_med', 'NSMI_tot20',
#        'NSMI_med20', 'TSS_tot', 'TSS_mean', 'TSS_med', 'TSS_tot20',
#        'TSS_mean20', 'TSS_med20', 'NSMI_totpix20', 'TSS_totpix20',
#        'NSMI_totpix80', 'TSS_totpix80'],
#       dtype='object')

# %%
plt.scatter(df_sed_L8h["date"], df_sed_L8h["TSS_tot"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L80["date"], df_sed_L80["TSS_tot"], label="L8 Port")

plt.legend()
plt.ylabel("TSS tot")
# Out:
# Text(0, 0.5, 'TSS tot')

# %%
plt.scatter(df_sed_L8h["date"], df_sed_L8h["NSMI_tot"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L80["date"], df_sed_L80["NSMI_tot"], label="L8 Port")

plt.legend()
plt.ylabel("NSMI tot")
# Out:
# Text(0, 0.5, 'NSMI tot')

# %%
plt.scatter(df_sed_L8h["date"], df_sed_L8h["NSMI_totpix80"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L80["date"], df_sed_L80["NSMI_totpix80"], label="L8 Port")

plt.legend()
plt.ylabel("NSMI n of pixel > 80 quantiles")
# Out:
# Text(0, 0.5, 'NSMI n of pixel > 80 quantiles')

# %%
plt.scatter(df_sed_L8h["date"], df_sed_L8h["TSS_totpix80"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L80["date"], df_sed_L80["TSS_totpix80"], label="L8 Port")

plt.legend()
plt.ylabel("TSS n of pixel > 80 quantiles")
# Out:
# Text(0, 0.5, 'TSS n of pixel > 80 quantiles')

# %%
df_sed_L70 = pd.read_csv('L7_sediment_centre.csv')  
df_sed_L7h = pd.read_csv('L7_sediment_hayling.csv')  
df_sed_L70["date"] = pd.to_datetime(df_sed_L70['date'])
df_sed_L7h["date"] = pd.to_datetime(df_sed_L7h['date'])

df_sed_S20 = pd.read_csv('S2_sediment_centre.csv')  
df_sed_S2h = pd.read_csv('S2_sediment_hayling.csv')  
df_sed_S20["date"] = pd.to_datetime(df_sed_S20['date'])
df_sed_S2h["date"] = pd.to_datetime(df_sed_S2h['date'])

# %%
plt.scatter(df_sed_L80["date"], df_sed_L80["TSS_totpix80"], label="L8 Port")

plt.scatter(df_sed_L70["date"], df_sed_L70["TSS_totpix80"], label="L7 Port")

plt.scatter(df_sed_S20["date"], df_sed_S20["TSS_totpix80"], label="L7 Port")

plt.scatter(df_sed_L8h["date"], df_sed_L8h["TSS_totpix80"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L7h["date"], df_sed_L7h["TSS_totpix80"], label="L7 Hayling Island", facecolor="None", edgecolor="orange")
plt.scatter(df_sed_S2h["date"], df_sed_S2h["TSS_totpix80"], label="L7 Hayling Island", facecolor="None", edgecolor="green")

plt.legend()
plt.ylabel("TSS n of pixel > 80 quantiles")
# Out:
# Text(0, 0.5, 'TSS n of pixel > 80 quantiles')

# %%
plt.scatter(df_sed_L80["date"], df_sed_L80["TSS_totpix20"], label="L8 Port")

plt.scatter(df_sed_L70["date"], df_sed_L70["TSS_totpix20"], label="L7 Port")

plt.scatter(df_sed_S20["date"], df_sed_S20["TSS_totpix20"], label="L7 Port")

plt.scatter(df_sed_L8h["date"], df_sed_L8h["TSS_totpix20"], label="L8 Hayling Island", facecolor="None", edgecolor="blue")
plt.scatter(df_sed_L7h["date"], df_sed_L7h["TSS_totpix20"], label="L7 Hayling Island", facecolor="None", edgecolor="orange")
plt.scatter(df_sed_S2h["date"], df_sed_S2h["TSS_totpix20"], label="L7 Hayling Island", facecolor="None", edgecolor="green")

plt.legend()
plt.ylabel("TSS n of pixel > 80 quantiles")
# Out:
# Text(0, 0.5, 'TSS n of pixel > 80 quantiles')
